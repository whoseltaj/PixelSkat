# %%
#1
import os
import random
import time

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import (
    LearningRateScheduler, EarlyStopping, ModelCheckpoint, TensorBoard
)
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import TopKCategoricalAccuracy

import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report



seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
#2
INITIAL_LR = 1e-3

def lr_schedule(epoch):

    return INITIAL_LR * (0.99 ** epoch)

scheduler = LearningRateScheduler(lr_schedule)

# %%
#3
train = np.load("../data/train.npz")
val   = np.load("../data/val.npz")
test  = np.load("../data/test.npz")

X_train, y_train = train['X'], train['Y']
X_val,   y_val   = val['X'],   val['Y']
X_test,  y_test  = test['X'],  test['Y']

# %%
#4
y_train_oh = tf.one_hot(y_train, depth=32)
y_val_oh   = tf.one_hot(y_val,   depth=32)
y_test_oh  = tf.one_hot(y_test,  depth=32)

# %%
#5
print("Train:", X_train.shape, y_train.shape)
print("Val:  ",    X_val.shape,   y_val.shape)
print("Test: ",    X_test.shape,  y_test.shape)
# Out:
# Train: (56000, 255) (56000,)
# Val:   (12000, 255) (12000,)
# Test:  (12000, 255) (12000,)

# %%
#6
model = models.Sequential([
    layers.Input(shape=(255,), name="input_features"),

    layers.Dense(256, activation='relu',
                 kernel_regularizer=regularizers.l2(1e-5),
                 name="dense_1"),
    #stabilize activations
    layers.BatchNormalization(name="bn_1"),
    layers.Dropout(0.5, name="dropout_1"),

    layers.Dense(128, activation='relu',
                 kernel_regularizer=regularizers.l2(1e-5),
                 name="dense_2"),
    #another BatchNorm
    layers.BatchNormalization(name="bn_2"),
    layers.Dropout(0.5, name="dropout_2"),

    layers.Dense(64, activation='relu',
                 kernel_regularizer=regularizers.l2(1e-5),
                 name="dense_3"),
    layers.BatchNormalization(name="bn_3"),
    layers.Dropout(0.5, name="dropout_3"),

    layers.Dense(32, activation='softmax', name="output")
])

# %%
#7
loss = CategoricalCrossentropy(
    from_logits=False,
    label_smoothing=0.1
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=loss,
    metrics=[
        'accuracy',
        TopKCategoricalAccuracy(k=3, name='top_3_accuracy')
    ]
)

# %%
#8
tf.keras.utils.plot_model(
    model,
    to_file="3hl_model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False, dpi=150, show_layer_activations=True, show_trainable=True
)

# %%
#9
es   = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)
ckpt = ModelCheckpoint(
    "best_three_hl_model.keras",
    save_best_only=True
)
tb = TensorBoard(log_dir="../logs/three_hl")

start = time.time()
history = model.fit(
    X_train, y_train_oh,
    validation_data=(X_val, y_val_oh),
    epochs=30,
    batch_size=64,
    callbacks=[scheduler, es, ckpt, tb]
)
total_time = time.time() - start
time_per_epoch = total_time / len(history.history['loss'])
print(f"Training time: {total_time:.1f}s ≃ {time_per_epoch:.2f}s/epoch")
# Out:
# Epoch 1/30
# 875/875 [==============================] - 4s 3ms/step - loss: 2.9949 - accuracy: 0.2396 - top_3_accuracy: 0.4443 - val_loss: 1.8232 - val_accuracy: 0.5269 - val_top_3_accuracy: 0.8448 - lr: 0.0010
# Epoch 2/30
# 875/875 [==============================] - 2s 3ms/step - loss: 2.2049 - accuracy: 0.4636 - top_3_accuracy: 0.7276 - val_loss: 1.6423 - val_accuracy: 0.5397 - val_top_3_accuracy: 0.8612 - lr: 9.9000e-04
# Epoch 3/30
# 875/875 [==============================] - 2s 3ms/step - loss: 2.0459 - accuracy: 0.5041 - top_3_accuracy: 0.7714 - val_loss: 1.5948 - val_accuracy: 0.5440 - val_top_3_accuracy: 0.8671 - lr: 9.8010e-04
# Epoch 4/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.9761 - accuracy: 0.5220 - top_3_accuracy: 0.7865 - val_loss: 1.5771 - val_accuracy: 0.5456 - val_top_3_accuracy: 0.8677 - lr: 9.7030e-04
# Epoch 5/30
# 875/875 [==============================] - 2s 2ms/step - loss: 1.9392 - accuracy: 0.5311 - top_3_accuracy: 0.7968 - val_loss: 1.5793 - val_accuracy: 0.5419 - val_top_3_accuracy: 0.8698 - lr: 9.6060e-04
# Epoch 6/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.9191 - accuracy: 0.5334 - top_3_accuracy: 0.7996 - val_loss: 1.5573 - val_accuracy: 0.5536 - val_top_3_accuracy: 0.8712 - lr: 9.5099e-04
# Epoch 7/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.9022 - accuracy: 0.5399 - top_3_accuracy: 0.8027 - val_loss: 1.5493 - val_accuracy: 0.5574 - val_top_3_accuracy: 0.8718 - lr: 9.4148e-04
# Epoch 8/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8820 - accuracy: 0.5409 - top_3_accuracy: 0.8102 - val_loss: 1.5443 - val_accuracy: 0.5606 - val_top_3_accuracy: 0.8753 - lr: 9.3207e-04
# Epoch 9/30
# 875/875 [==============================] - 2s 2ms/step - loss: 1.8747 - accuracy: 0.5448 - top_3_accuracy: 0.8125 - val_loss: 1.5497 - val_accuracy: 0.5562 - val_top_3_accuracy: 0.8748 - lr: 9.2274e-04
# Epoch 10/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8592 - accuracy: 0.5469 - top_3_accuracy: 0.8160 - val_loss: 1.5389 - val_accuracy: 0.5565 - val_top_3_accuracy: 0.8718 - lr: 9.1352e-04
# Epoch 11/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8487 - accuracy: 0.5507 - top_3_accuracy: 0.8167 - val_loss: 1.5376 - val_accuracy: 0.5582 - val_top_3_accuracy: 0.8758 - lr: 9.0438e-04
# Epoch 12/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8449 - accuracy: 0.5480 - top_3_accuracy: 0.8181 - val_loss: 1.5378 - val_accuracy: 0.5612 - val_top_3_accuracy: 0.8739 - lr: 8.9534e-04
# Epoch 13/30
# 875/875 [==============================] - 2s 2ms/step - loss: 1.8391 - accuracy: 0.5510 - top_3_accuracy: 0.8217 - val_loss: 1.5406 - val_accuracy: 0.5589 - val_top_3_accuracy: 0.8751 - lr: 8.8638e-04
# Epoch 14/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8301 - accuracy: 0.5551 - top_3_accuracy: 0.8229 - val_loss: 1.5377 - val_accuracy: 0.5596 - val_top_3_accuracy: 0.8742 - lr: 8.7752e-04
# Epoch 15/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8203 - accuracy: 0.5598 - top_3_accuracy: 0.8269 - val_loss: 1.5345 - val_accuracy: 0.5624 - val_top_3_accuracy: 0.8712 - lr: 8.6875e-04
# Epoch 16/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8190 - accuracy: 0.5598 - top_3_accuracy: 0.8252 - val_loss: 1.5292 - val_accuracy: 0.5627 - val_top_3_accuracy: 0.8737 - lr: 8.6006e-04
# Epoch 17/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8206 - accuracy: 0.5555 - top_3_accuracy: 0.8262 - val_loss: 1.5336 - val_accuracy: 0.5605 - val_top_3_accuracy: 0.8754 - lr: 8.5146e-04
# Epoch 18/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.8103 - accuracy: 0.5616 - top_3_accuracy: 0.8275 - val_loss: 1.5318 - val_accuracy: 0.5647 - val_top_3_accuracy: 0.8757 - lr: 8.4294e-04
# Epoch 19/30
# 875/875 [==============================] - 2s 2ms/step - loss: 1.7999 - accuracy: 0.5644 - top_3_accuracy: 0.8303 - val_loss: 1.5336 - val_accuracy: 0.5614 - val_top_3_accuracy: 0.8751 - lr: 8.3451e-04
# Epoch 20/30
# 875/875 [==============================] - 2s 2ms/step - loss: 1.7943 - accuracy: 0.5671 - top_3_accuracy: 0.8317 - val_loss: 1.5332 - val_accuracy: 0.5648 - val_top_3_accuracy: 0.8735 - lr: 8.2617e-04
# Epoch 21/30
# 875/875 [==============================] - 2s 3ms/step - loss: 1.7950 - accuracy: 0.5679 - top_3_accuracy: 0.8320 - val_loss: 1.5310 - val_accuracy: 0.5627 - val_top_3_accuracy: 0.8765 - lr: 8.1791e-04
# Training time: 48.6s ≃ 2.31s/epoch

# %%
#10
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))


plt.subplot(1,2,1)
plt.plot(history.history['loss'],     label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title("Cross Entropy Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],           label='train@1')
plt.plot(history.history['val_accuracy'],       label='val@1')
plt.plot(history.history['top_3_accuracy'],     '--', label='train@3')
plt.plot(history.history['val_top_3_accuracy'], '--', label='val@3')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
#11
val_loss_final = history.history['val_loss'][-1]
val_acc_final  = history.history['val_accuracy'][-1]
val_top3_final = history.history['val_top_3_accuracy'][-1]

print("Val Loss:   ", val_loss_final)
print("Val Acc:    ", val_acc_final)
print("Val Top-3:  ", val_top3_final)
# Out:
# Val Loss:    1.530963659286499
# Val Acc:     0.562749981880188
# Val Top-3:   0.8765000104904175

# %%
#12
test_loss, test_acc, test_top3 = model.evaluate(
    X_test, y_test_oh,
    batch_size=64, verbose=0
)
print("Test Loss:      ", test_loss)
print("Test Top-1 Acc: ", test_acc)
print("Test Top-3 Acc: ", test_top3)
# Out:
# Test Loss:       1.5203042030334473
# Test Top-1 Acc:  0.5704166889190674
# Test Top-3 Acc:  0.8788333535194397

# %%
#13
probs    = model.predict(X_test, batch_size=64)
y_onehot = y_test_oh.numpy()

mse = np.mean((probs - y_onehot)**2)
mae = np.mean(np.abs(probs - y_onehot))

print("Test MSE: ", mse)
print("Test MAE: ", mae)
# Out:
# 188/188 [==============================] - 1s 3ms/step
# Test MSE:  0.015247109
# Test MAE:  0.032345384

# %%
#14
train_acc_final  = history.history['accuracy'][-1]
train_top3_final = history.history['top_3_accuracy'][-1]

gap_acc  = train_acc_final  - val_acc_final
gap_top3 = train_top3_final - val_top3_final

print("Gap Top-1 Acc:", gap_acc)
print("Gap Top-3 Acc:", gap_top3)
# Out:
# Gap Top-1 Acc: 0.005178570747375488
# Gap Top-3 Acc: -0.0445178747177124

# %%
#15
model.save("three_hidden_layer_model.keras")

# %%
#16
metrics_3hl = {
    'test_loss':      test_loss,
    'test_acc':       test_acc,
    'test_top3':      test_top3,
    'val_loss':       val_loss_final,
    'val_acc':        val_acc_final,
    'val_top3':       val_top3_final,
    'mse':            mse,
    'mae':            mae,
    'gap_acc':        gap_acc,
    'time_per_epoch': time_per_epoch
}

metrics_3hl
# Out:
# {'test_loss': 1.5203042030334473,
#  'test_acc': 0.5704166889190674,
#  'test_top3': 0.8788333535194397,
#  'val_loss': 1.530963659286499,
#  'val_acc': 0.562749981880188,
#  'val_top3': 0.8765000104904175,
#  'mse': 0.015247109,
#  'mae': 0.032345384,
#  'gap_acc': 0.005178570747375488,
#  'time_per_epoch': 2.9439080896831693}

# %%
#17
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val   shape:", X_val.shape)
print("y_val   shape:", y_val.shape)
print("X_test  shape:", X_test.shape)
print("y_test  shape:", y_test.shape)
# Out:
# X_train shape: (56000, 255)
# y_train shape: (56000,)
# X_val   shape: (12000, 255)
# y_val   shape: (12000,)
# X_test  shape: (12000, 255)
# y_test  shape: (12000,)

# %%
#18
preds = model.predict(X_test, batch_size=64).argmax(axis=1)

print("\nFirst 5 X_test rows:\n", X_test[:5])
print("First 5 model predictions:", preds[:5])
print("First 5 ground-truth labels:", y_test[:5])
# Out:
# 188/188 [==============================] - 1s 3ms/step
#
# First 5 X_test rows:
#  [[0.         1.         0.         ... 0.         0.         0.11666667]
#  [0.         0.         0.         ... 0.18333334 0.30833334 0.        ]
#  [0.         1.         1.         ... 0.04166667 0.         0.        ]
#  [0.         0.         0.         ... 0.         0.19166666 0.36666667]
#  [0.         0.         0.         ... 0.11666667 0.31666666 0.20833333]]
# First 5 model predictions: [ 1  8 25 17 15]
# First 5 ground-truth labels: [30  8 25  4 12]

# %%
#19
# Pick and copy a test sample
sample_index = 0
base = X_test[sample_index:sample_index+1].copy()

# Flip a random feature
feature_to_flip = np.random.randint(0, base.shape[1])
modified = base.copy()
modified[0, feature_to_flip] = 1.0 - modified[0, feature_to_flip]

# Get probabilities
base_probs = model.predict(base, verbose=0)[0]
mod_probs  = model.predict(modified, verbose=0)[0]

print(f"Flipped feature index: {feature_to_flip}")
print("Base top-3 scores:", np.sort(base_probs)[-3:])
print("Mod top-3 scores:", np.sort(mod_probs)[-3:])
print("Base top-3 indices:", base_probs.argsort()[-3:][::-1])
print("Mod top-3 indices:", mod_probs.argsort()[-3:][::-1])
# Out:
# Flipped feature index: 102
# Base top-3 scores: [0.12307435 0.1271216  0.13838935]
# Mod top-3 scores: [0.12307435 0.1271216  0.13838935]
# Base top-3 indices: [1 4 7]
# Mod top-3 indices: [1 4 7]

# %%
#20
import matplotlib.pyplot as plt

predictions = model.predict(X_test).argmax(axis=1)
residuals   = y_test.flatten() - predictions

plt.figure(figsize=(10,6))
plt.scatter(predictions, residuals, alpha=0.5, cmap='coolwarm', s=10)
plt.hlines(0, xmin=predictions.min(), xmax=predictions.max(),
           colors='r', linestyles='--')
plt.xlabel('Predicted Class')
plt.ylabel('Residual (True – Pred)')
plt.title('Residual Plot')
plt.grid(True, linestyle='--', alpha=0.5)
plt.colorbar(label='Residual Value')
plt.show()
# Out:
# 375/375 [==============================] - 1s 1ms/step
# C:\Users\eltaj\AppData\Local\Temp\ipykernel_6288\2154276463.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(predictions, residuals, alpha=0.5, cmap='coolwarm', s=10)

# %%
#21
from scipy.stats import pearsonr

pred_labels = model.predict(X_test).argmax(axis=1)

plt.figure(figsize=(6,6))
plt.scatter(y_test, pred_labels, alpha=0.3, s=8)
plt.plot([0,31],[0,31],'r--')
plt.xlabel("True Card Index")
plt.ylabel("Predicted Card Index")
plt.title("True vs. Predicted Card Indices")
plt.show()

corr, _ = pearsonr(y_test.flatten(), pred_labels)
print(f"Pearson r between true and predicted labels: {corr:.3f}")
# Out:
# 375/375 [==============================] - 1s 3ms/step
# Pearson r between true and predicted labels: 0.745

# %%
#22
# New: reliability curve for max‐prob predictions
from sklearn.calibration import calibration_curve
probs       = model.predict(X_val)               
max_p       = probs.max(axis=1)
is_correct  = (probs.argmax(axis=1) == y_val)

frac_pos, mean_pred = calibration_curve(
    is_correct, max_p, n_bins=10, strategy='uniform'
)

plt.figure(figsize=(6,6))
plt.plot(mean_pred, frac_pos, marker='o')
plt.plot([0,1],[0,1],'k--')
plt.xlabel("Mean Predicted Probability")
plt.ylabel("Fraction Correct")
plt.title("Reliability Diagram")
plt.show()
# Out:
# 375/375 [==============================] - 1s 3ms/step

# %%
#23
preds = model.predict(X_test).argmax(axis=1)
cm    = confusion_matrix(y_test, preds, labels=range(32))

plt.figure(figsize=(10,8))
sns.heatmap(cm, cmap="Blues", fmt="d", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 375/375 [==============================] - 1s 3ms/step
